# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"}

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
response = requests.get(url, headers=headers)
results = response.json()
print(results)
# Out:
# {'total_count': 203699, 'pagination': {'page_count': 892, 'current_page': 1, 'per_page': 84}, 'sort': 'popularity', 'articles': [{'sku': 'CO411A0NL-A11', 'name': 'CHUCK TAYLOR ALL STAR LIFT - Baskets basses - white/garnet/navy', 'price': {'original': '79,95\xa0€', 'promotional': '71,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['36', '36.5', '37', '37.5', '38', '39', '39.5', '40', '41', '41.5', '42'], 'url_key': 'converse-chuck-taylor-all-star-lift-baskets-basses-whitegarnetnavy-co411a0nl-a11', 'media': [{'path': 'CO/41/1A/0N/LA/11/CO411A0NL-A11@13.jpg', 'role': 'DEFAULT', 'packet_shot': False}], 'brand_name': 'Converse', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': '-10%', 'tracking_value': 'discount rate'}], 'product_group': 'shoe', 'delivery_promises': []}, {'sku': 'AD116D0TK-A11', 'name': 'STAN SMITH - Baskets basses - footwear white/true pink', 'price': {'original': '59,95\xa0€', 'promotional': '44,90\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3'], 'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitetrue-pink-ad116d0tk-a11', 'media': [{'path': 'AD/11/6D/0T/KA/11/AD116D0TK-A11@11.jpg', 'role': 'DEFAULT', 'packet_shot': False}], 'brand_name': 'adidas Originals', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': 'Jusqu’à -25%', 'tracking_value': 'discount rate'}], 'product_group': 'shoe', 'delivery_promises': []}, {'sku': 'AD111A0S2-A11', 'name': 'STAN SMITH - Baskets basses - footwear white/solar orange', 'price': {'original': '99,95\xa0€', 'promotional': '74,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['36', '38', '40', '42', '36 2/3', '37 1/3', '38 2/3', '39 1/3', '40 2/3', '41 1/3', '42 2/3', '43 1/3'], 'url_key': 'adidas-originals-baskets-basses-footwear-whitesolar-orange-ad111a0s2-a11', 'media': [{'path': 'AD/11/1A/0S/2A/11/AD111A0S2-A11@13.jpg', 'role': 'DEFAULT', 'packet_shot': False}], 'brand_name': 'adidas Originals', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'campaign', 'value': 'HOT DROP', 'tracking_value': 'mu_sneaker_releases'}, {'key': 'discountRate', 'value': '-25%', 'tracking_value': 'discount rate'}], 'product_group': 'shoe', 'delivery_promises': []}, {'sku': 'AD111A0KP-A14', 'name': 'STAN SMITH - Baskets basses - footwear white/offwhite/ecru tint', 'price': {'original': '99,95\xa0€', 'promotional': '74,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['36', '38', '40', '42', '36 2/3', '37 1/3', '38 2/3', '39 1/3', '40 2/3', '41 1/3', '42 2/3', '43 1/3'], 'url_key': 'adidas-originals-stan-smith-exclusive-baskets-basses-ad111a0kp-a14', 'media': [{'path': 'AD/11/1A/0K/PA/14/AD111A0KP-A14@9.jpg', 'role': 'DEFAULT', 'packet_shot': False}], 'brand_name': 'adidas Originals', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': '-25%', 'tracking_value': 'discount rate'}], 'product_group': 'shoe', 'outfits': [{'id': 'V2ixuOb0TrK', 'url_key': '/outfits/V2ixuOb0TrK', 'media': [{'path': 'dc09cf3a621d451594eec15074af4569/80edb9756d884c37a5b5380d3a8a5ed2.jpeg', 'outline_reference': 'outfit_image'}], 'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9', 'gender': 'women', 'creator': {'id': 'd08577fb-ca60-472c-8288-c8e7cd078c8c', 'name': 'lolo_bravoo', 'media': [{'path': 'e55e9d3c7a52486b81f37d9851df7610/4952c74ecf734b168662111b2d348dcc.jpeg', 'outline_reference': 'creator_image'}]}, 'items': [{'id': 'GS121T01K-B11'} ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
